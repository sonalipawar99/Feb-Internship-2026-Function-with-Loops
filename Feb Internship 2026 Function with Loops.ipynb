# %% [markdown]
# # sonali vishal pawar batch=360
# # Feb Internship 2026 Function with Loops

# %% [markdown]
# ### Problem 1: Mobile Recharge Validation System
# ### Problem Statement:Create a function to validate a mobile recharge request.
# ### Rules: Recharge amount must be ≥ ₹50  Valid plans: 199, 299, 399, 599  User should be allowed to retry if invalid
# ### Real-Time Use
# ### Telecom recharge apps Payment gateways
# ### Hint:Use function for validation  Use while loop for retry

# %%
def validate_recharge(amount):
    valid_plans = [199, 299, 399, 599]

    if amount < 50:
        return "Amount should be at least ₹50"
    elif amount not in valid_plans:
        return "Invalid plan. Choose from 199, 299, 399, 599"
    else:
        return "Recharge Successful"

# Retry system
while True:
    amount = int(input("Enter recharge amount: "))
    result = validate_recharge(amount)
    print(result)

    if result == "Recharge Successful":
        break
# Out:
# Enter recharge amount:  299
# Recharge Successful

# %% [markdown]
# ### Problem 2: Inventory Reorder Alert System
# ### Problem Statement :Given a dictionary of products and stock quantities: Reorder Alert if stock < 15 Print Stock OK otherwise
# ### Real-Time Use Warehouse system  Retail management
# ### Hint:Use function Use for loop on dictionary

# %%
def check_inventory(products):
    for item, qty in products.items():
        if qty < 15:
            print(f"{item}: Reorder Alert")
        else:
            print(f"{item}: Stock OK")

# Example
products = {
    "Laptop": 10,
    "Mouse": 25,
    "Keyboard": 12,
    "Monitor": 20
}

check_inventory(products)
# Out:
# Laptop: Reorder Alert
# Mouse: Stock OK
# Keyboard: Reorder Alert
# Monitor: Stock OK

# %% [markdown]
# ### Problem 3: Student Result Processing System  Problem Statement
# ### Create a function that: Accepts a list of student marks Calculates average marks Prints Pass if average ≥ 50 else Fail
# ### Real-Time Use Online exam systems Evaluation portals
# ### Hint Use loop to calculate total Return result from function

# %%
def check_result(marks):
    total = 0

    for m in marks:
        total += m

    avg = total / len(marks)

    if avg >= 50:
        return f"Average = {avg}, Pass"
    else:
        return f"Average = {avg}, Fail"

# Example
marks = [60, 70, 45, 50]
print(check_result(marks))
# Out:
# Average = 56.25, Pass

# %% [markdown]
# ### Problem 4: Cab Fare Estimator with Retry Option
# ### Problem Statement:Create a cab fare calculator: Base fare = ₹50  ₹12 per km Peak hour → 25% extra Allow retry using while loop
# ### Real-Time Use Ride-hailing apps
# ### Transport systems HintFunction for fare calculation While loop for retry

# %%
def calculate_fare(distance, peak):
    fare = 50 + (distance * 12)

    if peak == "yes":
        fare += fare * 0.25

    return fare

# Retry system
while True:
    distance = float(input("Enter distance (km): "))
    peak = input("Is it peak hour? (yes/no): ")

    fare = calculate_fare(distance, peak)
    print("Total Fare =", fare)

    retry = input("Do you want to calculate again? (yes/no): ")
    if retry != "yes":
        break
# Out:
# Enter distance (km):  100
# Is it peak hour? (yes/no):  yes
# Total Fare = 1562.5
# Do you want to calculate again? (yes/no):  yes
# Enter distance (km):  100
# Is it peak hour? (yes/no):  no
# Total Fare = 1250.0
# Do you want to calculate again? (yes/no):  no

# %% [markdown]
# ### Problem 5: Employee Attendance Eligibility Checker
# ### Problem Statement:Create a function that: Accepts attendance list ("P", "A") Calculates attendance percentage Returns Eligible if ≥ 75% else Not Eligible
# ### Real-Time Use HR payroll systems
# ### Internship tracking Hint Use loop to count present days Use return statement

# %%
def check_attendance(attendance):
    present = 0

    for day in attendance:
        if day == "P":
            present += 1

    percentage = (present / len(attendance)) * 100

    if percentage >= 75:
        return f"Attendance = {percentage}%, Eligible"
    else:
        return f"Attendance = {percentage}%, Not Eligible"

# Example
attendance = ["P", "P", "A", "P", "P", "A", "P"]
print(check_attendance(attendance))
# Out:
# Attendance = 71.42857142857143%, Not Eligible

# %% [markdown]
# ### Problem 6: Password Strength Checker
# ### Problem Statement :Create a function to check password strength.Rules:Minimum length = 8 Must contain at least one digit Must contain at least one special character (@#$) Real-Time Use Login systems Security validation
# ### Hint:Use loop over string Use conditions inside function

# %%
def check_password(password):
    if len(password) < 8:
        return "Weak Password (min 8 characters required)"

    has_digit = False
    has_special = False
    special_chars = "@#$"

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_chars:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password (must include digit and special char)"

# Example
pwd = input("Enter password: ")
print(check_password(pwd))
# Out:
# Enter password:  sonali0666@
# Strong Password
